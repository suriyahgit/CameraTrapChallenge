# %%
# Out:
# Package                           Version
# --------------------------------- ---------------------
# absl-py                           1.3.0
# affine                            2.3.1
# aiohttp                           3.8.3
# aiosignal                         1.3.1
# alabaster                         0.7.12
# alembic                           1.8.1
# anyio                             3.6.2
# appdirs                           1.4.4
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# ase                               3.22.1
# astroid                           2.12.13
# asttokens                         2.2.1
# astunparse                        1.6.3
# async-generator                   1.10
# async-timeout                     4.0.2
# atomicwrites                      1.4.1
# attrs                             22.1.0
# autopep8                          1.6.0
# awkward                           2.0.0
# ...
